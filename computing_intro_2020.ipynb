# %% [markdown]
# ## python and scientific computing

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Installing Anaconda, virtual environments and packages

# %% [markdown]
# ### Why virtual environment and dependency management?
#
# ![image.png](attachment:image.png)
#
#
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Why Anaconda?
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### What about miniconda?
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### download and install anaconda
# - https://www.anaconda.com/products/individual
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Create and use virtual environments
#
# - https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Create virtualenv from yml
#
# ![image-4.png](attachment:image-4.png)
#
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Anaconda Navigator
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Activate ve and start jupyter notebook
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Data types
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Import packages, set options

# %%
#getting and working with data
import pandas as pd
import numpy as np
import math
import re
import os

#stats
import scipy as sp
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols

#visualizing results
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_context('poster', rc={'font.size':35,
                              'axes.titlesize':50,
                              'axes.labelsize':35})

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import warnings; warnings.simplefilter('ignore')
np.set_printoptions(suppress=True)

# %% [markdown]
# ## Get data

# %%
path = 'C:/Users/Schindler/Documents/Schindler_Lab/Data/Analysis/excel_files/VNS/final_VNSorig.xlsx'

# %%
df = pd.read_excel(path)
df = pd.DataFrame(data = df)
print(df.shape)
df.head()
# Out:
# (46, 411)
# ...

# %%
df['Round_main'].value_counts()
# Out:
# VNS_r3    24
# VNS_r4    22
# Name: Round_main, dtype: int64

# %%
sns.catplot(x="Group", y='OFB_Cdelay_168d', data=df, ci=68, kind='bar', height=9)
